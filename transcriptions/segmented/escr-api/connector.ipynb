# %% [markdown]
# # eScriptorium API
#
# Programatically downloads PAGE-XML from eScriptorium.

# %% [markdown]
# ## Imports, Gubbins

# %%
# imports

from escriptorium_connector import EscriptoriumConnector
import os
from dotenv import load_dotenv
import io

# load environment variables

load_dotenv()
url = str(os.getenv('ESCRIPTORIUM_URL'))
username = str(os.getenv('ESCRIPTORIUM_USERNAME'))
password = str(os.getenv('ESCRIPTORIUM_PASSWORD'))
escr = EscriptoriumConnector(url, username, password) 

my_documents = escr.get_documents()
document_pk = my_documents.results[0].pk
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/digital-anon/venv/lib/python3.12/site-packages/escriptorium_connector/connector.py:220, in EscriptoriumConnector.__init__.<locals>.assert_status_hook(response, *args, **kwargs)
#     219 try:
# --> 220     response.raise_for_status()
#     221 except requests.HTTPError as err:
#
# File ~/Documents/digital-anon/venv/lib/python3.12/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://ju.flw.uantwerpen.be/api/documents?page=2
#
# During handling of the above exception, another exception occurred:
#
# EscriptoriumConnectorHttpError            Traceback (most recent call last)
# Cell In[5], line 16
#      13 password = str(os.getenv('ESCRIPTORIUM_PASSWORD'))
#      14 escr = EscriptoriumConnector(url, username, password)
# ---> 16 my_documents = escr.get_documents()
#      17 document_pk = my_documents.results[0].pk
#
# File ~/Documents/digital-anon/venv/lib/python3.12/site-packages/escriptorium_connector/connector.py:451, in EscriptoriumConnector.get_documents(self)
#     450 def get_documents(self) -> GetDocuments:
# --> 451     return self.__get_paginated_response(f"{self.api_url}documents/", GetDocuments)
#
# File ~/Documents/digital-anon/venv/lib/python3.12/site-packages/escriptorium_connector/connector.py:387, in EscriptoriumConnector.__get_paginated_response(self, url, return_cls)
#     385 info = all_docs
#     386 while info.next is not None:
# --> 387     info = self.__get_url_serialized(info.next, return_cls)
#     388     all_docs.results = all_docs.results + info.results
#     390 return all_docs
#
# File ~/Documents/digital-anon/venv/lib/python3.12/site-packages/escriptorium_connector/connector.py:360, in EscriptoriumConnector.__get_url_serialized(self, url, return_cls)
#     359 def __get_url_serialized(self, url: str, return_cls: Type[T]) -> T:
# --> 360     r = self.http.get(url)
#     361     return self.__serialize_response(r, url, return_cls)
#
# File ~/Documents/digital-anon/venv/lib/python3.12/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~/Documents/digital-anon/venv/lib/python3.12/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/Documents/digital-anon/venv/lib/python3.12/site-packages/requests/sessions.py:723, in Session.send(self, request, **kwargs)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~/Documents/digital-anon/venv/lib/python3.12/site-packages/requests/sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File ~/Documents/digital-anon/venv/lib/python3.12/site-packages/requests/sessions.py:708, in Session.send(self, request, **kwargs)
#     705 r.elapsed = timedelta(seconds=elapsed)
#     707 # Response manipulation hooks
# --> 708 r = dispatch_hook("response", hooks, r, **kwargs)
#     710 # Persist cookies
#     711 if r.history:
#     712
#     713     # If the hooks create history then we want those cookies too
#
# File ~/Documents/digital-anon/venv/lib/python3.12/site-packages/requests/hooks.py:30, in dispatch_hook(key, hooks, hook_data, **kwargs)
#      28     hooks = [hooks]
#      29 for hook in hooks:
# ---> 30     _hook_data = hook(hook_data, **kwargs)
#      31     if _hook_data is not None:
#      32         hook_data = _hook_data
#
# File ~/Documents/digital-anon/venv/lib/python3.12/site-packages/escriptorium_connector/connector.py:222, in EscriptoriumConnector.__init__.<locals>.assert_status_hook(response, *args, **kwargs)
#     220     response.raise_for_status()
#     221 except requests.HTTPError as err:
# --> 222     raise EscriptoriumConnectorHttpError(err.response.text, err)
#
# EscriptoriumConnectorHttpError: <!DOCTYPE HTML>
# <html>
#
# <head>
#
#     <meta charset="utf-8">
#
#     <title>Jupyter Server</title>
#     <link id="favicon" rel="shortcut icon" type="image/x-icon" href="/static/favicon.ico?v=50afa725b5de8b00030139d09b38620224d4e7dba47c07ef0e86d4643f30c9bfe6bb7e1a4a1c561aa32834480909a4b6fe7cd1e17f7159330b6b5914bf45a880">
#
#     <link rel="stylesheet" href="/static/style/bootstrap.min.css?v=0e8a7fbd6de23ad6b27ab95802a0a0915af6693af612bc304d83af445529ce5d95842309ca3405d10f538d45c8a3a261b8cff78b4bd512dd9effb4109a71d0ab" />
#     <link rel="stylesheet" href="/static/style/bootstrap-theme.min.css?v=8b2f045cb5b4d5ad346f6e816aa2566829a4f5f2783ec31d80d46a57de8ac0c3d21fe6e53bcd8e1f38ac17fcd06d12088bc9b43e23b5d1da52d10c6b717b22b3" />
#     <link rel="stylesheet" href="/static/style/index.css?v=30372e3246a801d662cf9e3f9dd656fa192eebde9054a2282449fe43919de9f0ee9b745d7eb49d3b0a5e56357912cc7d776390eddcab9dac85b77bdb17b4bdae" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
#
#
#
# <style type="text/css">
#     /* disable initial hide */
#     div#header,
#     div#site {
#         display: block;
#     }
# </style>
#
#
#
#
#
# </head>
#
# <body class=""    dir="ltr">
#
#   <noscript>
#     <div id='noscript'>
#       Jupyter Server requires JavaScript.<br>
#       Please enable it to proceed.
#     </div>
#   </noscript>
#
#   <div id="header" role="navigation" aria-label="Top Menu">
#     <div id="header-container" class="container">
#       <div id="jupyter_server" class="nav navbar-brand"><a href="/lab" title='dashboard'>
#           <img src='/static/logo/logo.png?v=a2a176ee3cee251ffddf5fa21fe8e43727a9e5f87a06f9c91ad7b776d9e9d3d5e0159c16cc188a3965e00375fb4bc336c16067c688f5040c0c2d4bfdb852a9e4' alt='Jupyter Server' />
#         </a></div>
#
#
#
#
#
#
#
#     </div>
#     <div class="header-bar"></div>
#
#
#
#   </div>
#
#   <div id="site">
#
#
# <div class="error">
#
#     <h1>404 : Not Found</h1>
#
#
# <p>You are requesting a page that does not exist!</p>
#
# </div>
#
#
#   </div>
#
#
#
#
#
#
#
#   <script type='text/javascript'>
#     function _remove_token_from_url() {
#       if (window.location.search.length <= 1) {
#         return;
#       }
#       var search_parameters = window.location.search.slice(1).split('&');
#       for (var i = 0; i < search_parameters.length; i++) {
#         if (search_parameters[i].split('=')[0] === 'token') {
#           // remote token from search parameters
#           search_parameters.splice(i, 1);
#           var new_search = '';
#           if (search_parameters.length) {
#             new_search = '?' + search_parameters.join('&');
#           }
#           var new_url = window.location.origin +
#             window.location.pathname +
#             new_search +
#             window.location.hash;
#           window.history.replaceState({}, "", new_url);
#           return;
#         }
#       }
#     }
#     _remove_token_from_url();
#   </script>
# </body>
#
# </html>
